# %%
import tkinter as tk
import numpy as np
import sklearn
from tkinter import messagebox
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
iris=load_iris()
X_train,X_test,y_train,y_test=train_test_split(iris['data'],iris['target'],random_state=91,test_size=0.62)

knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
score=knn.score(X_test,y_test)
score="{0:.2f}".format(score*100)
score
# Out:
# '98.92'

# %%
file=open('model.txt','w')
file.write(str(knn))
file.close()

# %%
root=tk.Tk()
root.title("Iris Dataset Prediction")
root.geometry("400x400+300+100")


#--------------------------
def train():
    try:
        random_state=int(E1.get())
        test_size=int(E2.get())
        X_train,X_test,y_train,y_test=train_test_split(iris['data'],iris['target'],random_state=random_state,test_size=test_size/100)
        knn=KNeighborsClassifier(n_neighbors=int(E7.get()))
        knn.fit(X_train,y_train)
        score=knn.score(X_test,y_test)
        score="{0:.2f}".format(score*100)
        L2.config(text=score)
        messagebox.showinfo('Success',"Model Trained Successfully")
    except:
        tk.messagebox.showinfo('Error',"Training Model Failed!")

def predict():
    try:
        new_feature=[float(E3.get()),float(E4.get()),float(E5.get()),float(E6.get())]
        X_new=np.array([new_feature])
        prediction=knn.predict(X_new)
        prediction=iris['target_names'][prediction][0]
        L3.config(text=prediction)
        messagebox.showinfo('Success',"Prediction Complete")
    except:
        tk.messagebox.showinfo('Error',"Prediction Failed!")
#--------------------------
L1=tk.Label(root,text="-"*45,fg="black",font=('bold',20))
L1.pack()
L1.place(x=0,y=0)
#--------------------------
L1=tk.Label(root,text="Train Model",fg="black",font=('bold',12))
L1.pack()
L1.place(x=30,y=10)
L1=tk.Label(root,text="Random State :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=20,y=50)
L1=tk.Label(root,text="Test Size :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=160,y=50)
L1=tk.Label(root,text="Accuracy :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=270,y=50)
L2=tk.Label(root,text='',fg="black",font=('bold',9))
L2.pack()
L2.place(x=325,y=50)

E1=tk.Entry(root,width=5)
E1.pack()
E1.place(x=110,y=52)
E1.insert(0,91)
E2=tk.Entry(root,width=5)
E2.pack()
E2.place(x=220,y=52)
E2.insert(0,62)

L1=tk.Label(root,text="No. of Nearest Neighbours :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=20,y=75)
E7=tk.Entry(root,width=5)
E7.pack()
E7.place(x=170,y=77)
E7.insert(0,3)

B1=tk.Button(root,text="TRAIN",command=train)
B1.pack()
B1.place(x=320,y=80)

#--------------------------

X_train,X_test,y_train,y_test=train_test_split(iris['data'],iris['target'],random_state=91,test_size=0.62)
knn=KNeighborsClassifier(n_neighbors=int(E7.get()))
knn.fit(X_train,y_train)
score=knn.score(X_test,y_test)
score="{0:.2f}".format(score*100)
train()
#--------------------------

L1=tk.Label(root,text="-"*45,fg="black",font=('bold',20))
L1.pack()
L1.place(x=0,y=110)
#--------------------------
L1=tk.Label(root,text="Prediction",fg="black",font=('bold',12))
L1.pack()
L1.place(x=30,y=120)
L1=tk.Label(root,text="Sepal length :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=50,y=180)
L1=tk.Label(root,text="Sepal Width :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=210,y=180)
L1=tk.Label(root,text="Petal Length :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=50,y=230)
L1=tk.Label(root,text="Petal Width :",fg="black",font=('bold',9))
L1.pack()
L1.place(x=210,y=230)

E3=tk.Entry(root,width=5)
E3.pack()
E3.place(x=130,y=182)
E4=tk.Entry(root,width=5)
E4.pack()
E4.place(x=287,y=182)
E5=tk.Entry(root,width=5)
E5.pack()
E5.place(x=130,y=232)
E6=tk.Entry(root,width=5)
E6.pack()
E6.place(x=287,y=232)

B1=tk.Button(root,text="PREDICT",command=predict)
B1.pack()
B1.place(x=320,y=265)
#--------------------------
L1=tk.Label(root,text=" Preidcted Class :",fg="black",font=('bold',12))
L1.pack()
L1.place(x=80,y=300)
L3=tk.Label(root,text="<null>",fg="black",font=('bold',12))
L3.pack()
L3.place(x=210,y=300)
#--------------------------
root.resizable(width=False,height=False)
root.mainloop()
